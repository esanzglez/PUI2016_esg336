# %% [markdown]
# ## Assigment 1: 5 Distributions

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import pylab as pl
from scipy.stats import norm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['norm']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### Chisquared

# %%
#distributions = ['pois', 'gaus', 'chisq', 'cauchy', 'lnorm', 'binomial']
distributions = ['chisq']

# %%
mymean = 100
df=mymean
np.random.seed(336)

# %%
md ={}
md

md['chisq'] = np.random.chisquare(df, size=100)
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ##### Figure 1: Chi sq distribution: df = 100, N=100

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 100.95, standard deviation: 14.31

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['chisq'] = {} 
for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)
        
    
for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()

        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# #### Figure 2: Graphical represantion of the Central Limit Theorem where it can be seen that having a distribution larger enough it will aproximate to a Gauss Distribution.

# %%
allmeans_chisq = list(md['chisq']['means'].values())

pl.figure(figsize=(5,5))
pl.hist(allmeans_chisq,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
#  #### Figure 3: Histogram of the means possible means of 100 samples of the Chisquared Distribution

# %% [markdown]
# ### Normal distribution

# %%
distributions = ['lnorm']

# %%
mymean = 100
df=mymean
np.random.seed(336)

md ={}
md

md['lnorm'] = np.random.normal(df,size=100)

pl.hist(md['lnorm'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

pl.show()

# %% [markdown]
# ##### Figure 4: Normal Distribution: df = 100, N=100

# %%
print ("Normal mean: %.2f, standard deviation: %.2f"%(md['lnorm'].mean(), md['lnorm'].std()))
# Out:
# Normal mean: 99.98, standard deviation: 0.96

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['lnorm'] = {} 
for n in mysize:
    md['lnorm'][n] =  np.random.normal(df,size=100)
    
md['lnorm']['means'] = {}
axchlnorm_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)
        
    
for nn in md['lnorm']:
    if not type(nn) == str:
        md['lnorm']['means'][nn] = md['lnorm'][nn].mean()

        axchlnorm_mu_n.plot(nn, md['lnorm']['means'][nn], 'o')
        axchlnorm_mu_n.set_xlabel('sample size', fontsize=18)
        axchlnorm_mu_n.set_ylabel('sample mean', fontsize=18)
        axchlnorm_mu_n.set_title('Normal Distribution', fontsize=18)
        axchlnorm_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ##### Figure 5: Graphical represantion of the Central Limit Theorem where it can be seen that having a distribution larger enough it will aproximate to a Gauss Distribution.

# %%
allmeans_norm = list(md['lnorm']['means'].values())

pl.figure(figsize=(5,5))
pl.hist(allmeans_norm,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
#  #### Figure 6: Histogram of the means possible means of 100 samples of the Normal Distribution

# %% [markdown]
# ### Poisson distribution

# %%
distributions = ['pois']

# %%
mymean = float(100)
df=mymean

# %%
md ={}
md
np.random.seed(336)
md['pois'] = np.random.poisson(df, size=100)

pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ##### Figure 7: Poisson distribution: df = 100, N=100

# %%
print ("Poisson mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# Poisson mean: 101.07, standard deviation: 9.47

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['pois'] = {} 
for n in mysize:
    md['pois'][n] = np.random.poisson(df, size=100)
   
md['pois']['means'] = {}
axchpoiss_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)
    
for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()

        axchpoiss_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axchpoiss_mu_n.set_xlabel('sample size', fontsize=18)
        axchpoiss_mu_n.set_ylabel('sample mean', fontsize=18)
        axchpoiss_mu_n.set_title('Poisson Distribution', fontsize=18)
        axchpoiss_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# #### Figure 8: Graphical represantion of the Central Limit Theorem where it can be seen that having any distribution larger enough it will aproximate to a Gauss Distribution.

# %%
allmeans_pois = list(md['pois']['means'].values())

pl.figure(figsize=(5,5))
pl.hist(allmeans_norm,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
#  #### Figure 9: Histogram of the means possible means of 100 samples of the Poisson

# %% [markdown]
# ### Binomial distribution

# %%
distributions = ['bin']

# %%
mymean = float(100)
df=mymean
np.random.seed(336)

# %%
md ={}
md

md['bin'] = np.random.binomial(200,0.5,size=100)

pl.hist(md['bin'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ##### Figure 10: Binomial distribution: df = 100, N=100

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['bin'].mean(), md['bin'].std()))
# Out:
# Binomial mean: 100.31, standard deviation: 7.80

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['bin'] = {} 
for n in mysize:
    md['bin'][n] = np.random.poisson(df, size=100)
   
md['bin']['means'] = {}
axchpoiss_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)
    
for nn in md['bin']:
    if not type(nn) == str:
        md['bin']['means'][nn] = md['bin'][nn].mean()

        axchpoiss_mu_n.plot(nn, md['bin']['means'][nn], 'o')
        axchpoiss_mu_n.set_xlabel('sample size', fontsize=18)
        axchpoiss_mu_n.set_ylabel('sample mean', fontsize=18)
        axchpoiss_mu_n.set_title('Binomial Distribution', fontsize=18)
        axchpoiss_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# #### Figure 11: Graphical represantion of the Central Limit Theorem where it can be seen that having any distribution larger enough it will aproximate to a Gauss Distribution

# %%
allmeans_bin = list(md['bin']['means'].values())

pl.figure(figsize=(5,5))
pl.hist(allmeans_norm,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
#  #### Figure 12: Histogram of the means possible means of 100 samples of the Binomial Distribution

# %% [markdown]
# ### Laplace

# %%
distributions = ['lplace']

# %%
mymean =(100)
df=mymean
np.random.seed(336)

# %%
md ={}
md

md['lplace'] = np.random.laplace(df,size=100)

pl.hist(md['lplace'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ##### Figure 13: Laplace distribution: df = 100, N=100

# %%
print ("Laplace mean: %.2f, standard deviation: %.2f"%(md['lplace'].mean(), md['lplace'].std()))
# Out:
# Laplace mean: 100.17, standard deviation: 1.42

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['lplace'] = {} 
for n in mysize:
    md['lplace'][n] = np.random.poisson(df, size=100)
   
md['lplace']['means'] = {}
axchpoiss_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)
    
for nn in md['lplace']:
    if not type(nn) == str:
        md['lplace']['means'][nn] = md['lplace'][nn].mean()

        axchpoiss_mu_n.plot(nn, md['lplace']['means'][nn], 'o')
        axchpoiss_mu_n.set_xlabel('sample size', fontsize=18)
        axchpoiss_mu_n.set_ylabel('sample mean', fontsize=18)
        axchpoiss_mu_n.set_title('Laplace Distribution', fontsize=18)
        axchpoiss_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# #### Figure 14: Graphical represantion of the Central Limit Theorem where it can be seen that having any distribution larger enough it will aproximate to a Gauss Distribution

# %%
allmeans_laplace = list(md['lplace']['means'].values())

pl.figure(figsize=(5,5))
pl.hist(allmeans_norm,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 15: Histogram of the means possible means of 100 samples of the Laplace Distribution

# %% [markdown]
# ## All the means together

# %%
pl.figure(figsize=(5,5))
pl.hist((allmeans_chisq,allmeans_norm,allmeans_pois,allmeans_bin,allmeans_laplace),bins=30,stacked=True)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.legend(('Chisquared','Normal','Poisson','Binomial','LaPlace'),loc='upper right',bbox_to_anchor=(1.5,1))

# %% [markdown]
# #### Figure 16: Histogram of all means of the five distribution for un sample of 100
